# %%
import pandas as pd
import numpy as np

# Ruta relativa (funciona en tu Mac si los CSV están en prediccion-ingresos/data/)
TRAIN_PATH = "../data/train.csv"
TEST_PATH  = "../data/test.csv"

df = pd.read_csv(TRAIN_PATH)

df.head(), df.shape
